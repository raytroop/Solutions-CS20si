# %%
""" word2vec with NCE loss and code to visualize the embeddings on TensorBoard
Author: Chip Huyen
Prepared for the class CS 20SI: "TensorFlow for Deep Learning Research"
cs20si.stanford.edu
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
from tensorflow.contrib.tensorboard.plugins import projector
import tensorflow as tf

from process_data import process_data
import utils

VOCAB_SIZE = 50000
BATCH_SIZE = 128
EMBED_SIZE = 128 # dimension of the word embedding vectors
SKIP_WINDOW = 1 # the context window
NUM_SAMPLED = 64    # Number of negative examples to sample.
LEARNING_RATE = 1.0
NUM_TRAIN_STEPS = 100000
WEIGHTS_FLD = 'processed/'
SKIP_STEP = 2000

# %%
tf.reset_default_graph()

# %%
class SkipGramModel:
    """ Build the graph for word2vec model """
    def __init__(self, vocab_size, embed_size, batch_size, num_sampled, learning_rate):
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.batch_size = batch_size
        self.num_sampled = num_sampled
        self.lr = learning_rate
        self.global_step = tf.Variable(0, dtype=tf.int32, trainable=False, name='global_step')

    def _create_placeholders(self):
        """ Step 1: define the placeholders for input and output """
        with tf.name_scope("data"):
            self.center_words = tf.placeholder(tf.int32, shape=[self.batch_size], name='center_words')
            self.target_words = tf.placeholder(tf.int32, shape=[self.batch_size, 1], name='target_words')

    def _create_embedding(self):
        """ Step 2: define weights. In word2vec, it's actually the weights that we care about """
        # Assemble this part of the graph on the CPU. You can change it to GPU if you have GPU
        #with tf.device('/gpu:0'):
        with tf.name_scope("embed"):
            self.embed_matrix = tf.Variable(tf.random_uniform([self.vocab_size, 
                                                                    self.embed_size], -1.0, 1.0), 
                                                                    name='embed_matrix')

    def _create_loss(self):
        """ Step 3 + 4: define the model + the loss function """
        #with tf.device('/gpu:0'):
        with tf.name_scope("loss"):
                # Step 3: define the inference
            embed = tf.nn.embedding_lookup(self.embed_matrix, self.center_words, name='embed')

                # Step 4: define loss function
                # construct variables for NCE loss
            nce_weight = tf.Variable(tf.truncated_normal([self.vocab_size, self.embed_size],
                                                            stddev=1.0 / (self.embed_size ** 0.5)), 
                                                            name='nce_weight')
            nce_bias = tf.Variable(tf.zeros([VOCAB_SIZE]), name='nce_bias')

                # define loss function to be NCE loss function
            self.loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weight, 
                                                    biases=nce_bias, 
                                                    labels=self.target_words, 
                                                    inputs=embed, 
                                                    num_sampled=self.num_sampled, 
                                                    num_classes=self.vocab_size), name='loss')
    def _create_optimizer(self):
        """ Step 5: define optimizer """
        #with tf.device('/gpu:0'):
        self.optimizer = tf.train.GradientDescentOptimizer(self.lr).minimize(self.loss, 
                                                              global_step=self.global_step)

    def _create_summaries(self):
        with tf.name_scope("summaries"):
            tf.summary.scalar("loss", self.loss)
            tf.summary.histogram("histogram_loss", self.loss)
            # because you have several summaries, we should merge them all
            # into one op to make it easier to manage
            self.summary_op = tf.summary.merge_all()

    def build_graph(self):
        """ Build the graph for our model """
        self._create_placeholders()
        self._create_embedding()
        self._create_loss()
        self._create_optimizer()
        self._create_summaries()

def train_model(model, batch_gen, num_train_steps, weights_fld):
    saver = tf.train.Saver() # defaults to saving all variables - in this case embed_matrix, nce_weight, nce_bias

    initial_step = 0
    utils.make_dir('checkpoints')
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        #ckpt = tf.train.get_checkpoint_state(os.path.dirname('checkpoints/checkpoint'))
        ckpt = tf.train.get_checkpoint_state(os.path.dirname('checkpoints/'))
        print (ckpt)
        # if that checkpoint exists, restore from checkpoint
        if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)

        total_loss = 0.0 # we use this to calculate late average loss in the last SKIP_STEP steps
        writer = tf.summary.FileWriter('improved_graph/lr' + str(LEARNING_RATE), sess.graph)
        initial_step = model.global_step.eval()
        for index in range(initial_step, initial_step + num_train_steps):
            centers, targets = next(batch_gen)
            feed_dict={model.center_words: centers, model.target_words: targets}
            loss_batch, _, summary = sess.run([model.loss, model.optimizer, model.summary_op], 
                                              feed_dict=feed_dict)
            writer.add_summary(summary, global_step=index)
            total_loss += loss_batch
            if (index + 1) % SKIP_STEP == 0:
                print('Average loss at step {}: {:5.1f}'.format(index, total_loss / SKIP_STEP))
                total_loss = 0.0
                saver.save(sess, 'checkpoints/skip-gram', index)
        
        ####################
        # code to visualize the embeddings. uncomment the below to visualize embeddings
        # run "'tensorboard --logdir='processed'" to see the embeddings
        # final_embed_matrix = sess.run(model.embed_matrix)
        
        # # it has to variable. constants don't work here. you can't reuse model.embed_matrix
        # embedding_var = tf.Variable(final_embed_matrix[:1000], name='embedding')
        # sess.run(embedding_var.initializer)

        # config = projector.ProjectorConfig()
        # summary_writer = tf.summary.FileWriter('processed')

        # # add embedding to the config file
        # embedding = config.embeddings.add()
        # embedding.tensor_name = embedding_var.name
        
        # # link this tensor to its metadata file, in this case the first 500 words of vocab
        # embedding.metadata_path = 'processed/vocab_1000.tsv'

        # # saves a configuration file that TensorBoard will read during startup.
        # projector.visualize_embeddings(summary_writer, config)
        # saver_embed = tf.train.Saver([embedding_var])
        # saver_embed.save(sess, 'processed/model3.ckpt', 1)

# %% [markdown]
# >tf.train.Saver(var_list=None, reshape=False, sharded=False, **max_to_keep=5**, keep_checkpoint_every_n_hours=10000.0, name=None, restore_sequentially=False, saver_def=None, builder=None, defer_build=False, allow_empty=False, write_version=2, pad_step_number=False, save_relative_paths=False, filename=None)

# %% [markdown]
# ```python
# def main():
#     model = SkipGramModel(VOCAB_SIZE, EMBED_SIZE, BATCH_SIZE, NUM_SAMPLED, LEARNING_RATE)
#     model.build_graph()
#     batch_gen = process_data(VOCAB_SIZE, BATCH_SIZE, SKIP_WINDOW)
#     train_model(model, batch_gen, NUM_TRAIN_STEPS, WEIGHTS_FLD)
#
# if __name__ == '__main__':
#     main()
#     ```

# %%
model = SkipGramModel(VOCAB_SIZE, EMBED_SIZE, BATCH_SIZE, NUM_SAMPLED, LEARNING_RATE)
model.build_graph()
batch_gen = process_data(VOCAB_SIZE, BATCH_SIZE, SKIP_WINDOW)
train_model(model, batch_gen, NUM_TRAIN_STEPS, WEIGHTS_FLD)
# Out:
# Dataset ready
# model_checkpoint_path: "checkpoints\\skip-gram-99999"
# all_model_checkpoint_paths: "checkpoints\\skip-gram-91999"
# all_model_checkpoint_paths: "checkpoints\\skip-gram-93999"
# all_model_checkpoint_paths: "checkpoints\\skip-gram-95999"
# all_model_checkpoint_paths: "checkpoints\\skip-gram-97999"
# all_model_checkpoint_paths: "checkpoints\\skip-gram-99999"
#
# INFO:tensorflow:Restoring parameters from checkpoints\skip-gram-99999
# Average loss at step 101999:   4.8
# Average loss at step 103999:   4.8
# Average loss at step 105999:   4.8
# Average loss at step 107999:   4.8
# Average loss at step 109999:   4.7
# Average loss at step 111999:   4.7
# Average loss at step 113999:   4.7
# Average loss at step 115999:   4.6
# Average loss at step 117999:   4.5
# Average loss at step 119999:   4.7
# Average loss at step 121999:   4.6
# Average loss at step 123999:   4.6
# Average loss at step 125999:   4.6
# Average loss at step 127999:   4.7
# Average loss at step 129999:   4.6
# Average loss at step 131999:   4.6
# Average loss at step 133999:   4.6
# Average loss at step 135999:   4.6
# Average loss at step 137999:   4.5
# Average loss at step 139999:   4.5
# Average loss at step 141999:   4.5
# Average loss at step 143999:   4.5
# Average loss at step 145999:   4.6
# Average loss at step 147999:   4.6
# Average loss at step 149999:   4.5
# Average loss at step 151999:   4.5
# Average loss at step 153999:   4.6
# Average loss at step 155999:   4.5
# Average loss at step 157999:   4.6
# Average loss at step 159999:   4.5
# Average loss at step 161999:   4.5
# Average loss at step 163999:   4.4
# Average loss at step 165999:   4.3
# Average loss at step 167999:   4.5
# Average loss at step 169999:   4.5
# Average loss at step 171999:   4.5
# Average loss at step 173999:   4.5
# Average loss at step 175999:   4.5
# Average loss at step 177999:   4.5
# Average loss at step 179999:   4.4
# Average loss at step 181999:   4.5
# Average loss at step 183999:   4.5
# Average loss at step 185999:   4.5
# Average loss at step 187999:   4.5
# Average loss at step 189999:   4.5
# Average loss at step 191999:   4.5
# Average loss at step 193999:   4.5
# Average loss at step 195999:   4.5
# Average loss at step 197999:   4.4
# Average loss at step 199999:   4.5

# %%
model = SkipGramModel(VOCAB_SIZE, EMBED_SIZE, BATCH_SIZE, NUM_SAMPLED, LEARNING_RATE)
model.build_graph()

# %%
tf.get_default_graph().as_graph_def()
# Out:
# node {
#   name: "global_step/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "global_step"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "global_step/Assign"
#   op: "Assign"
#   input: "global_step"
#   input: "global_step/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@global_step"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "global_step/read"
#   op: "Identity"
#   input: "global_step"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@global_step"
#       }
#     }
#   }
# }
# node {
#   name: "data/center_words"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 128
#         }
#       }
#     }
#   }
# }
# node {
#   name: "data/target_words"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 128
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "P\303\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -1.0
#       }
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "embed/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/sub"
#   op: "Sub"
#   input: "embed/random_uniform/max"
#   input: "embed/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "embed/random_uniform/mul"
#   op: "Mul"
#   input: "embed/random_uniform/RandomUniform"
#   input: "embed/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "embed/random_uniform"
#   op: "Add"
#   input: "embed/random_uniform/mul"
#   input: "embed/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "embed/embed_matrix"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 50000
#         }
#         dim {
#           size: 128
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "embed/embed_matrix/Assign"
#   op: "Assign"
#   input: "embed/embed_matrix"
#   input: "embed/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@embed/embed_matrix"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "embed/embed_matrix/read"
#   op: "Identity"
#   input: "embed/embed_matrix"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@embed/embed_matrix"
#       }
#     }
#   }
# }
# node {
#   name: "loss/embed"
#   op: "Gather"
#   input: "embed/embed_matrix/read"
#   input: "data/center_words"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@embed/embed_matrix"
#       }
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "P\303\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal/mean"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal/stddev"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0883883461356163
#       }
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal/TruncatedNormal"
#   op: "TruncatedNormal"
#   input: "loss/truncated_normal/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal/mul"
#   op: "Mul"
#   input: "loss/truncated_normal/TruncatedNormal"
#   input: "loss/truncated_normal/stddev"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/truncated_normal"
#   op: "Add"
#   input: "loss/truncated_normal/mul"
#   input: "loss/truncated_normal/mean"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_weight"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 50000
#         }
#         dim {
#           size: 128
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "loss/nce_weight/Assign"
#   op: "Assign"
#   input: "loss/nce_weight"
#   input: "loss/truncated_normal"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_weight/read"
#   op: "Identity"
#   input: "loss/nce_weight"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
# }
# node {
#   name: "loss/zeros"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 50000
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 50000
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "loss/nce_bias/Assign"
#   op: "Assign"
#   input: "loss/nce_bias"
#   input: "loss/zeros"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_bias/read"
#   op: "Identity"
#   input: "loss/nce_bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_bias"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Cast"
#   op: "Cast"
#   input: "data/target_words"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape"
#   op: "Reshape"
#   input: "loss/nce_loss/Cast"
#   input: "loss/nce_loss/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/LogUniformCandidateSampler"
#   op: "LogUniformCandidateSampler"
#   input: "loss/nce_loss/Cast"
#   attr {
#     key: "num_sampled"
#     value {
#       i: 64
#     }
#   }
#   attr {
#     key: "num_true"
#     value {
#       i: 1
#     }
#   }
#   attr {
#     key: "range_max"
#     value {
#       i: 50000
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "unique"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/StopGradient"
#   op: "StopGradient"
#   input: "loss/nce_loss/LogUniformCandidateSampler"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT64
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/StopGradient_1"
#   op: "StopGradient"
#   input: "loss/nce_loss/LogUniformCandidateSampler:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/StopGradient_2"
#   op: "StopGradient"
#   input: "loss/nce_loss/LogUniformCandidateSampler:2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat"
#   op: "ConcatV2"
#   input: "loss/nce_loss/Reshape"
#   input: "loss/nce_loss/StopGradient"
#   input: "loss/nce_loss/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/embedding_lookup"
#   op: "Gather"
#   input: "loss/nce_weight/read"
#   input: "loss/nce_loss/concat"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice"
#   op: "StridedSlice"
#   input: "loss/nce_loss/Shape"
#   input: "loss/nce_loss/strided_slice/stack"
#   input: "loss/nce_loss/strided_slice/stack_1"
#   input: "loss/nce_loss/strided_slice/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 1
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack/1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack"
#   op: "Pack"
#   input: "loss/nce_loss/strided_slice"
#   input: "loss/nce_loss/stack/1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice/begin"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\000\000\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice"
#   op: "Slice"
#   input: "loss/nce_loss/embedding_lookup"
#   input: "loss/nce_loss/Slice/begin"
#   input: "loss/nce_loss/stack"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_1/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_1/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_1/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_1"
#   op: "StridedSlice"
#   input: "loss/nce_loss/Shape_1"
#   input: "loss/nce_loss/strided_slice_1/stack"
#   input: "loss/nce_loss/strided_slice_1/stack_1"
#   input: "loss/nce_loss/strided_slice_1/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 1
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack_1/1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack_1"
#   op: "Pack"
#   input: "loss/nce_loss/strided_slice_1"
#   input: "loss/nce_loss/stack_1/1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_1/size"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\377\377\377\377\377\377\377\377"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_1"
#   op: "Slice"
#   input: "loss/nce_loss/embedding_lookup"
#   input: "loss/nce_loss/stack_1"
#   input: "loss/nce_loss/Slice_1/size"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/MatMul"
#   op: "MatMul"
#   input: "loss/embed"
#   input: "loss/nce_loss/Slice_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/embedding_lookup_1"
#   op: "Gather"
#   input: "loss/nce_bias/read"
#   input: "loss/nce_loss/concat"
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_bias"
#       }
#     }
#   }
#   attr {
#     key: "validate_indices"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_2/begin"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_2"
#   op: "Slice"
#   input: "loss/nce_loss/embedding_lookup_1"
#   input: "loss/nce_loss/Slice_2/begin"
#   input: "loss/nce_loss/Shape_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape_3"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_3/size"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Slice_3"
#   op: "Slice"
#   input: "loss/nce_loss/embedding_lookup_1"
#   input: "loss/nce_loss/Shape_3"
#   input: "loss/nce_loss/Slice_3/size"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape_4"
#   op: "Shape"
#   input: "loss/nce_loss/Slice"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_2/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_2/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_2/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_2"
#   op: "StridedSlice"
#   input: "loss/nce_loss/Shape_4"
#   input: "loss/nce_loss/strided_slice_2/stack"
#   input: "loss/nce_loss/strided_slice_2/stack_1"
#   input: "loss/nce_loss/strided_slice_2/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_1/values_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\377\377\377\377\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_1"
#   op: "ConcatV2"
#   input: "loss/nce_loss/concat_1/values_0"
#   input: "loss/nce_loss/strided_slice_2"
#   input: "loss/nce_loss/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ExpandDims/dim"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ExpandDims"
#   op: "ExpandDims"
#   input: "loss/embed"
#   input: "loss/nce_loss/ExpandDims/dim"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tdim"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_1"
#   op: "Reshape"
#   input: "loss/nce_loss/Slice"
#   input: "loss/nce_loss/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Mul"
#   op: "Mul"
#   input: "loss/nce_loss/ExpandDims"
#   input: "loss/nce_loss/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_2/values_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_2"
#   op: "ConcatV2"
#   input: "loss/nce_loss/concat_2/values_0"
#   input: "loss/nce_loss/strided_slice_2"
#   input: "loss/nce_loss/concat_2/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_2"
#   op: "Reshape"
#   input: "loss/nce_loss/Mul"
#   input: "loss/nce_loss/concat_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Shape_5"
#   op: "Shape"
#   input: "loss/nce_loss/Reshape_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_3/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_3/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_3/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/strided_slice_3"
#   op: "StridedSlice"
#   input: "loss/nce_loss/Shape_5"
#   input: "loss/nce_loss/strided_slice_3/stack"
#   input: "loss/nce_loss/strided_slice_3/stack_1"
#   input: "loss/nce_loss/strided_slice_3/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 1
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack_2/1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/stack_2"
#   op: "Pack"
#   input: "loss/nce_loss/strided_slice_3"
#   input: "loss/nce_loss/stack_2/1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ones/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ones"
#   op: "Fill"
#   input: "loss/nce_loss/stack_2"
#   input: "loss/nce_loss/ones/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/MatMul_1"
#   op: "MatMul"
#   input: "loss/nce_loss/Reshape_2"
#   input: "loss/nce_loss/ones"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_3/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_3"
#   op: "Reshape"
#   input: "loss/nce_loss/MatMul_1"
#   input: "loss/nce_loss/Reshape_3/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_4/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\377\377\377\377\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_4"
#   op: "Reshape"
#   input: "loss/nce_loss/Reshape_3"
#   input: "loss/nce_loss/Reshape_4/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_5/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\377\377\377\377\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Reshape_5"
#   op: "Reshape"
#   input: "loss/nce_loss/Slice_2"
#   input: "loss/nce_loss/Reshape_5/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/add"
#   op: "Add"
#   input: "loss/nce_loss/Reshape_4"
#   input: "loss/nce_loss/Reshape_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/add_1"
#   op: "Add"
#   input: "loss/nce_loss/MatMul"
#   input: "loss/nce_loss/Slice_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Log"
#   op: "Log"
#   input: "loss/nce_loss/StopGradient_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/sub"
#   op: "Sub"
#   input: "loss/nce_loss/add"
#   input: "loss/nce_loss/Log"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/Log_1"
#   op: "Log"
#   input: "loss/nce_loss/StopGradient_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/sub_1"
#   op: "Sub"
#   input: "loss/nce_loss/add_1"
#   input: "loss/nce_loss/Log_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_3/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_3"
#   op: "ConcatV2"
#   input: "loss/nce_loss/sub"
#   input: "loss/nce_loss/sub_1"
#   input: "loss/nce_loss/concat_3/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ones_like/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\200\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ones_like/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/ones_like"
#   op: "Fill"
#   input: "loss/nce_loss/ones_like/Shape"
#   input: "loss/nce_loss/ones_like/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/truediv/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/truediv"
#   op: "RealDiv"
#   input: "loss/nce_loss/ones_like"
#   input: "loss/nce_loss/truediv/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/zeros_like"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 128
#           }
#           dim {
#             size: 64
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_4/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/nce_loss/concat_4"
#   op: "ConcatV2"
#   input: "loss/nce_loss/truediv"
#   input: "loss/nce_loss/zeros_like"
#   input: "loss/nce_loss/concat_4/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/zeros_like"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 128
#           }
#           dim {
#             size: 65
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/GreaterEqual"
#   op: "GreaterEqual"
#   input: "loss/nce_loss/concat_3"
#   input: "loss/sampled_losses/zeros_like"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/Select"
#   op: "Select"
#   input: "loss/sampled_losses/GreaterEqual"
#   input: "loss/nce_loss/concat_3"
#   input: "loss/sampled_losses/zeros_like"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/Neg"
#   op: "Neg"
#   input: "loss/nce_loss/concat_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/Select_1"
#   op: "Select"
#   input: "loss/sampled_losses/GreaterEqual"
#   input: "loss/sampled_losses/Neg"
#   input: "loss/nce_loss/concat_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/mul"
#   op: "Mul"
#   input: "loss/nce_loss/concat_3"
#   input: "loss/nce_loss/concat_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/sub"
#   op: "Sub"
#   input: "loss/sampled_losses/Select"
#   input: "loss/sampled_losses/mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/Exp"
#   op: "Exp"
#   input: "loss/sampled_losses/Select_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses/Log1p"
#   op: "Log1p"
#   input: "loss/sampled_losses/Exp"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/sampled_losses"
#   op: "Add"
#   input: "loss/sampled_losses/sub"
#   input: "loss/sampled_losses/Log1p"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\200\000\000\000A\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "loss/strided_slice/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/strided_slice/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "loss/strided_slice/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/strided_slice"
#   op: "StridedSlice"
#   input: "loss/Shape"
#   input: "loss/strided_slice/stack"
#   input: "loss/strided_slice/stack_1"
#   input: "loss/strided_slice/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 1
#     }
#   }
# }
# node {
#   name: "loss/stack/1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "loss/stack"
#   op: "Pack"
#   input: "loss/strided_slice"
#   input: "loss/stack/1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "loss/ones/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "loss/ones"
#   op: "Fill"
#   input: "loss/stack"
#   input: "loss/ones/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "loss/MatMul"
#   op: "MatMul"
#   input: "loss/sampled_losses"
#   input: "loss/ones"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "loss/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "loss/Reshape"
#   op: "Reshape"
#   input: "loss/MatMul"
#   input: "loss/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "loss/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "loss/loss"
#   op: "Mean"
#   input: "loss/Reshape"
#   input: "loss/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Fill"
#   op: "Fill"
#   input: "gradients/Shape"
#   input: "gradients/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/Fill"
#   input: "gradients/loss/loss_grad/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Tile/multiples"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Tile"
#   op: "Tile"
#   input: "gradients/loss/loss_grad/Reshape"
#   input: "gradients/loss/loss_grad/Tile/multiples"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tmultiples"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 128
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Const"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Prod"
#   op: "Prod"
#   input: "gradients/loss/loss_grad/Shape"
#   input: "gradients/loss/loss_grad/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Const_1"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Prod_1"
#   op: "Prod"
#   input: "gradients/loss/loss_grad/Shape_1"
#   input: "gradients/loss/loss_grad/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Maximum/y"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Maximum"
#   op: "Maximum"
#   input: "gradients/loss/loss_grad/Prod_1"
#   input: "gradients/loss/loss_grad/Maximum/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/floordiv"
#   op: "FloorDiv"
#   input: "gradients/loss/loss_grad/Prod"
#   input: "gradients/loss/loss_grad/Maximum"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/loss_grad/Shape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/loss_grad/Cast"
#   op: "Cast"
#   input: "gradients/loss/loss_grad/floordiv"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "SrcT"
# ...
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 1
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "gradients/loss/embed_grad/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/embed_grad/concat"
#   op: "ConcatV2"
#   input: "gradients/loss/embed_grad/ExpandDims"
#   input: "gradients/loss/embed_grad/strided_slice"
#   input: "gradients/loss/embed_grad/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/embed_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/AddN_2"
#   input: "gradients/loss/embed_grad/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/embed_grad/Reshape_1"
#   op: "Reshape"
#   input: "data/center_words"
#   input: "gradients/loss/embed_grad/ExpandDims"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Rank"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Shape"
#   op: "Shape"
#   input: "loss/nce_loss/Slice"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/stack/1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/stack"
#   op: "Pack"
#   input: "gradients/loss/nce_loss/Slice_grad/Rank"
#   input: "gradients/loss/nce_loss/Slice_grad/stack/1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Reshape"
#   op: "Reshape"
#   input: "loss/nce_loss/Slice/begin"
#   input: "gradients/loss/nce_loss/Slice_grad/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\300\000\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/sub"
#   op: "Sub"
#   input: "gradients/loss/nce_loss/Slice_grad/Shape_1"
#   input: "gradients/loss/nce_loss/Slice_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/sub_1"
#   op: "Sub"
#   input: "gradients/loss/nce_loss/Slice_grad/sub"
#   input: "loss/nce_loss/Slice/begin"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients/loss/nce_loss/Slice_grad/sub_1"
#   input: "gradients/loss/nce_loss/Slice_grad/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/concat"
#   op: "ConcatV2"
#   input: "gradients/loss/nce_loss/Slice_grad/Reshape"
#   input: "gradients/loss/nce_loss/Slice_grad/Reshape_1"
#   input: "gradients/loss/nce_loss/Slice_grad/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/Slice_grad/Pad"
#   op: "Pad"
#   input: "gradients/loss/nce_loss/Reshape_1_grad/Reshape"
#   input: "gradients/loss/nce_loss/Slice_grad/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tpaddings"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/AddN_3"
#   op: "AddN"
#   input: "gradients/loss/nce_loss/Slice_1_grad/Pad"
#   input: "gradients/loss/nce_loss/Slice_grad/Pad"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/loss/nce_loss/Slice_1_grad/Pad"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/Shape"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT64
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "P\303\000\000\000\000\000\000\200\000\000\000\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/ToInt32"
#   op: "Cast"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/Shape"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/Size"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 192
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/ExpandDims/dim"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/ExpandDims"
#   op: "ExpandDims"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/Size"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/ExpandDims/dim"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tdim"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice"
#   op: "StridedSlice"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/ToInt32"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack_1"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice/stack_2"
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 1
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/concat"
#   op: "ConcatV2"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/ExpandDims"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/strided_slice"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/AddN_3"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/loss/nce_loss/embedding_lookup_grad/Reshape_1"
#   op: "Reshape"
#   input: "loss/nce_loss/concat"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/ExpandDims"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "GradientDescent/learning_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_embed/embed_matrix/mul"
#   op: "Mul"
#   input: "gradients/loss/embed_grad/Reshape"
#   input: "GradientDescent/learning_rate"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@embed/embed_matrix"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_embed/embed_matrix/ScatterSub"
#   op: "ScatterSub"
#   input: "embed/embed_matrix"
#   input: "gradients/loss/embed_grad/Reshape_1"
#   input: "GradientDescent/update_embed/embed_matrix/mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@embed/embed_matrix"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_loss/nce_weight/mul"
#   op: "Mul"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/Reshape"
#   input: "GradientDescent/learning_rate"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_loss/nce_weight/ScatterSub"
#   op: "ScatterSub"
#   input: "loss/nce_weight"
#   input: "gradients/loss/nce_loss/embedding_lookup_grad/Reshape_1"
#   input: "GradientDescent/update_loss/nce_weight/mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_weight"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_loss/nce_bias/mul"
#   op: "Mul"
#   input: "gradients/loss/nce_loss/embedding_lookup_1_grad/Reshape"
#   input: "GradientDescent/learning_rate"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_bias"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_loss/nce_bias/ScatterSub"
#   op: "ScatterSub"
#   input: "loss/nce_bias"
#   input: "gradients/loss/nce_loss/embedding_lookup_1_grad/Reshape_1"
#   input: "GradientDescent/update_loss/nce_bias/mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@loss/nce_bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent/update"
#   op: "NoOp"
#   input: "^GradientDescent/update_embed/embed_matrix/ScatterSub"
#   input: "^GradientDescent/update_loss/nce_weight/ScatterSub"
#   input: "^GradientDescent/update_loss/nce_bias/ScatterSub"
# }
# node {
#   name: "GradientDescent/value"
#   op: "Const"
#   input: "^GradientDescent/update"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@global_step"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent"
#   op: "AssignAdd"
#   input: "global_step"
#   input: "GradientDescent/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@global_step"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "summaries/loss/tags"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#         }
#         string_val: "summaries/loss"
#       }
#     }
#   }
# }
# node {
#   name: "summaries/loss"
#   op: "ScalarSummary"
#   input: "summaries/loss/tags"
#   input: "loss/loss"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "summaries/histogram_loss/tag"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#         }
#         string_val: "summaries/histogram_loss"
#       }
#     }
#   }
# }
# node {
#   name: "summaries/histogram_loss"
#   op: "HistogramSummary"
#   input: "summaries/histogram_loss/tag"
#   input: "loss/loss"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "summaries/Merge/MergeSummary"
#   op: "MergeSummary"
#   input: "summaries/loss"
#   input: "summaries/histogram_loss"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
# }
# versions {
#   producer: 24
# }
